# %%
# %load_ext kedro.ipython
# Out:
# [11/25/24 11:22:24] INFO     Using                                                                  ]8;id=592207;file://C:\Users\33659\AppData\Roaming\mamba\envs\spaceflights310\lib\site-packages\kedro\framework\project\__init__.py\__init__.py]8;;\:]8;id=94911;file://C:\Users\33659\AppData\Roaming\mamba\envs\spaceflights310\lib\site-packages\kedro\framework\project\__init__.py#270\270]8;;\
#                              'C:\Users\33659\AppData\Roaming\mamba\envs\spaceflights310\lib\site-pa
#                              ckages\kedro\framework\project\rich_logging.yml' as logging
#                              configuration.
# [11/25/24 11:22:25] INFO     Registered line magic '%reload_kedro'                                   ]8;id=974988;file://C:\Users\33659\AppData\Roaming\mamba\envs\spaceflights310\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=331301;file://C:\Users\33659\AppData\Roaming\mamba\envs\spaceflights310\lib\site-packages\kedro\ipython\__init__.py#61\61]8;;\
#                     INFO     Registered line magic '%load_node'                                      ]8;id=63917;file://C:\Users\33659\AppData\Roaming\mamba\envs\spaceflights310\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=705856;file://C:\Users\33659\AppData\Roaming\mamba\envs\spaceflights310\lib\site-packages\kedro\ipython\__init__.py#63\63]8;;\
#                     INFO     Resolved project path as: C:\code\kedro-tutorial\spaceflights.         ]8;id=751355;file://C:\Users\33659\AppData\Roaming\mamba\envs\spaceflights310\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=775041;file://C:\Users\33659\AppData\Roaming\mamba\envs\spaceflights310\lib\site-packages\kedro\ipython\__init__.py#178\178]8;;\
#                              To set a different path, run '%reload_kedro <project_root>'
# [11/25/24 11:22:27] INFO     Kedro is sending anonymous usage data with the sole purpose of improving ]8;id=935173;file://C:\Users\33659\AppData\Roaming\mamba\envs\spaceflights310\lib\site-packages\kedro_telemetry\plugin.py\plugin.py]8;;\:]8;id=328725;file://C:\Users\33659\AppData\Roaming\mamba\envs\spaceflights310\lib\site-packages\kedro_telemetry\plugin.py#233\233]8;;\
#                              the product. No personal data or IP addresses are stored on our side. If
#                              you want to opt out, set the `KEDRO_DISABLE_TELEMETRY` or `DO_NOT_TRACK`
#                              environment variables, or create a `.telemetry` file in the current
#                              working directory with the contents `consent: false`. Read more at
#                              https://docs.kedro.org/en/stable/configuration/telemetry.html
# [11/25/24 11:22:28] INFO     Kedro project spaceflights                                             ]8;id=138934;file://C:\Users\33659\AppData\Roaming\mamba\envs\spaceflights310\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=956886;file://C:\Users\33659\AppData\Roaming\mamba\envs\spaceflights310\lib\site-packages\kedro\ipython\__init__.py#144\144]8;;\
#                     INFO     Defined global variable 'context', 'session', 'catalog' and            ]8;id=912178;file://C:\Users\33659\AppData\Roaming\mamba\envs\spaceflights310\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=491256;file://C:\Users\33659\AppData\Roaming\mamba\envs\spaceflights310\lib\site-packages\kedro\ipython\__init__.py#145\145]8;;\
#                              'pipelines'
# [11/25/24 11:22:29] INFO     Registered line magic 'run_viz'                                        ]8;id=607572;file://C:\Users\33659\AppData\Roaming\mamba\envs\spaceflights310\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=746621;file://C:\Users\33659\AppData\Roaming\mamba\envs\spaceflights310\lib\site-packages\kedro\ipython\__init__.py#151\151]8;;\

# %%
df = catalog.load("model_input_table")

df.head()
# Out:
#                     INFO     Loading data from model_input_table (ParquetDataset)...            ]8;id=245087;file://C:\Users\33659\AppData\Roaming\mamba\envs\spaceflights310\lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=912236;file://C:\Users\33659\AppData\Roaming\mamba\envs\spaceflights310\lib\site-packages\kedro\io\data_catalog.py#389\389]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#     id_x shuttle_location shuttle_type engine_type       engine_vendor  \
# 0  63561             Niue      Type V5     Quantum  ThetaBase Services
# 1  63561             Niue      Type V5     Quantum  ThetaBase Services
# 2  63561             Niue      Type V5     Quantum  ThetaBase Services
# 3  63561             Niue      Type V5     Quantum  ThetaBase Services
# 4  36260         Anguilla      Type V5     Quantum  ThetaBase Services
#
#    engines  passenger_capacity cancellation_policy  crew  d_check_complete  \
# 0      1.0                   2              strict   1.0             False
# 1      1.0                   2              strict   1.0             False
# 2      1.0                   2              strict   1.0             False
# 3      1.0                   2              strict   1.0             False
# 4      1.0                   2              strict   1.0              True
#
#    ...  review_scores_crew  review_scores_location  review_scores_price  \
# 0  ...                10.0                     9.0                 10.0
# 1  ...                10.0                     9.0                 10.0
# 2  ...                10.0                     9.0                 10.0
# 3  ...                10.0                     9.0                 10.0
# 4  ...                 9.0                     9.0                  9.0
#
#    number_of_reviews  reviews_per_month   id_y  company_rating  \
# 0                133               1.65  35029            1.00
# 1                133               1.65  35029            1.00
# 2                133               1.65  35029            1.00
# 3                133               1.65  35029            1.00
# 4                  3               0.09  30292            0.67
#
#    company_location  total_fleet_count  iata_approved
# 0              Niue                4.0          False
# 1              Niue                4.0          False
# 2              Niue                4.0          False
# 3              Niue                4.0          False
# 4          Anguilla                6.0          False
#
# [5 rows x 28 columns]

# %%
import sklearn

# %%
from sklearn.model_selection import train_test_split

# %%
features = [
    "engines",
    "passenger_capacity",
    "crew",
    "d_check_complete",
    "moon_clearance_complete",
    "iata_approved",
    "company_rating",
    "review_scores_rating"
]

# %%
X = df[features]
y = df["price"]

X.head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#    engines  passenger_capacity  crew  d_check_complete  \
# 0      1.0                   2   1.0             False
# 1      1.0                   2   1.0             False
# 2      1.0                   2   1.0             False
# 3      1.0                   2   1.0             False
# 4      1.0                   2   1.0              True
#
#    moon_clearance_complete  iata_approved  company_rating  \
# 0                    False          False            1.00
# 1                    False          False            1.00
# 2                    False          False            1.00
# 3                    False          False            1.00
# 4                    False          False            0.67
#
#    review_scores_rating
# 0                  97.0
# 1                  97.0
# 2                  97.0
# 3                  97.0
# 4                  90.0

# %%
y.head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 0    1325.0
# 1    1325.0
# 2    1325.0
# 3    1325.0
# 4    1780.0
# Name: price, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
len(X_train), len(X_test)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# (607687, 151922)

# %%
len(y_train), len(y_test)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# (607687, 151922)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.predict(X_test)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# array([1767.57121674, 3466.35138402, 5457.42195958, ..., 3787.9628453 ,
#        3069.29672982, 3587.88830571])

# %%
from sklearn.metrics import r2_score

# %%
y_predict = model.predict(X_test)

# %%
r2_score(y_test, y_predict)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 0.4457434798764165

# %%
import pandas as pd

# %%
def split_data(df: pd.DataFrame, params: dict) -> tuple:
    X = df[params["features"]]
    y = df["price"]
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=params["test_size"])
    X_train, X_test, y_train, y_test

# %%
# %reload_kedro
# Out:
# [11/25/24 11:52:03] INFO     Resolved project path as: C:\code\kedro-tutorial\spaceflights.         ]8;id=834246;file://C:\Users\33659\AppData\Roaming\mamba\envs\spaceflights310\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=291332;file://C:\Users\33659\AppData\Roaming\mamba\envs\spaceflights310\lib\site-packages\kedro\ipython\__init__.py#178\178]8;;\
#                              To set a different path, run '%reload_kedro <project_root>'
#                     INFO     Kedro is sending anonymous usage data with the sole purpose of improving ]8;id=207466;file://C:\Users\33659\AppData\Roaming\mamba\envs\spaceflights310\lib\site-packages\kedro_telemetry\plugin.py\plugin.py]8;;\:]8;id=798945;file://C:\Users\33659\AppData\Roaming\mamba\envs\spaceflights310\lib\site-packages\kedro_telemetry\plugin.py#233\233]8;;\
#                              the product. No personal data or IP addresses are stored on our side. If
#                              you want to opt out, set the `KEDRO_DISABLE_TELEMETRY` or `DO_NOT_TRACK`
#                              environment variables, or create a `.telemetry` file in the current
#                              working directory with the contents `consent: false`. Read more at
#                              https://docs.kedro.org/en/stable/configuration/telemetry.html
# [11/25/24 11:52:04] INFO     Kedro project spaceflights                                             ]8;id=868766;file://C:\Users\33659\AppData\Roaming\mamba\envs\spaceflights310\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=27921;file://C:\Users\33659\AppData\Roaming\mamba\envs\spaceflights310\lib\site-packages\kedro\ipython\__init__.py#144\144]8;;\
#                     INFO     Defined global variable 'context', 'session', 'catalog' and            ]8;id=891772;file://C:\Users\33659\AppData\Roaming\mamba\envs\spaceflights310\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=15074;file://C:\Users\33659\AppData\Roaming\mamba\envs\spaceflights310\lib\site-packages\kedro\ipython\__init__.py#145\145]8;;\
#                              'pipelines'
#                     INFO     Registered line magic 'run_viz'                                        ]8;id=527276;file://C:\Users\33659\AppData\Roaming\mamba\envs\spaceflights310\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=405298;file://C:\Users\33659\AppData\Roaming\mamba\envs\spaceflights310\lib\site-packages\kedro\ipython\__init__.py#151\151]8;;\

# %%
catalog.load("params:a")
# Out:
# [11/25/24 11:52:21] INFO     Loading data from params:a (MemoryDataset)...                      ]8;id=876782;file://C:\Users\33659\AppData\Roaming\mamba\envs\spaceflights310\lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=718715;file://C:\Users\33659\AppData\Roaming\mamba\envs\spaceflights310\lib\site-packages\kedro\io\data_catalog.py#389\389]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 1
